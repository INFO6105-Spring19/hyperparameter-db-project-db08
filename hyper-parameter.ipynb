# %%
import json
import pandas as pd
import numpy as np

# %%
L500= open("hlE1w6gySMelbourneHousingPrices_500_hy_parameter.json")
L800= open("ilkMo6dfRMelbourneHousingPrices_800_hy_parameter.json")
L1000=open("q077P1c6BMelbourneHousingPrices_1000_hy_parameter.json")
L1300=open("aGXJjUoV5MelbourneHousingPrices_1300_hy_parameter.json")
L1500=open('ljms5EdOlMelbourneHousingPrices_1500_hy_parameter.json')
d=json.load(L500)+json.load(L800)+json.load(L1000)+json.load(L1300)+json.load(L1500)

# %%
#GBM
model_name=[]
weights_column=[]
offset_column=[]
fold_column=[]
fold_assignment=[]
stopping_rounds=[]
max_runtime_secs=[]
stopping_metric=[]
stopping_tolerance=[]
balance_classes=[]
class_sampling_factors=[]
max_after_balance_size=[]
ntrees=[]
max_depth=[]
min_rows=[]
nbins=[]
nbins_top_level=[]
nbins_cats=[]
seed=[]
sample_rate=[]
sample_rate_per_class=[]
col_sample_rate_per_tree=[]
col_sample_rate_change_per_level=[]
min_split_improvement=[]
histogram_type=[]
learn_rate=[]
learn_rate_annealing=[]
col_sample_rate=[]
max_abs_leafnode_pred=[]
pred_noise_bandwidth=[]
distribution=[]
tweedie_power=[]
quantile_alpha=[]
huber_alpha=[]
categorical_encoding=[]

for i in range(len(d)):
    if d[i]['model_id']['actual']['name'].startswith('GBM'):
            model_name1=d[i]['model_id']['actual']['name']
            weights_column1= d[i]['weights_column']['actual']
            offset_column1= d[i]['offset_column']['actual']
            fold_column1= d[i]['fold_column']['actual']
            fold_assignment1= d[i]['fold_assignment']['actual']
            stopping_rounds1= d[i]['stopping_rounds']['actual']
            max_runtime_secs1= d[i]['max_runtime_secs']['actual']
            stopping_metric1= d[i]['stopping_metric']['actual']
            stopping_tolerance1= d[i]['stopping_tolerance']['actual']
            balance_classes1= d[i]['balance_classes']['actual']
            class_sampling_factors1= d[i]['class_sampling_factors']['actual']
            max_after_balance_size1= d[i]['max_after_balance_size']['actual']
            ntrees1= d[i]['ntrees']['actual']
            max_depth1= d[i]['max_depth']['actual']
            min_rows1= d[i]['min_rows']['actual']
            nbins1= d[i]['nbins']['actual']
            nbins_top_level1= d[i]['nbins_top_level']['actual']
            nbins_cats1= d[i]['nbins_cats']['actual']
            seed1= d[i]['seed']['actual']
            sample_rate1= d[i]['sample_rate']['actual']
            sample_rate_per_class1= d[i]['sample_rate_per_class']['actual']
            col_sample_rate_per_tree1= d[i]['col_sample_rate_per_tree']['actual']
            col_sample_rate_change_per_level1= d[i]['col_sample_rate_change_per_level']['actual']
            min_split_improvement1= d[i]['min_split_improvement']['actual']
            histogram_type1= d[i]['histogram_type']['actual']
            learn_rate1= d[i]['learn_rate']['actual']
            learn_rate_annealing1= d[i]['learn_rate_annealing']['actual']
            col_sample_rate1= d[i]['col_sample_rate']['actual']
            max_abs_leafnode_pred1= d[i]['max_abs_leafnode_pred']['actual']
            pred_noise_bandwidth1= d[i]['pred_noise_bandwidth']['actual']
            distribution1= d[i]['distribution']['actual']
            tweedie_power1= d[i]['tweedie_power']['actual']
            quantile_alpha1= d[i]['quantile_alpha']['actual']
            huber_alpha1= d[i]['huber_alpha']['actual']
            categorical_encoding1= d[i]['categorical_encoding']['actual']

            model_name.append(model_name1)
            weights_column.append(weights_column1) 
            offset_column.append(offset_column1)
            fold_column.append(fold_column1)
            fold_assignment.append(fold_assessment1)
            stopping_rounds.append(stopping_rounds1)
            max_runtime_secs.append( max_runtime_secs1)
            stopping_metric.append(stopping_metric1)
            stopping_tolerance.append(stopping_tolerance1)
            balance_classes.append(balance_classes1)
            class_sampling_factors.append(class_sampling_factors1)
            max_after_balance_size.append(max_after_balance_size1)
            ntrees.append(ntrees1)
            max_depth.append(max_depth1)
            min_rows.append(min_rows1)
            nbins.append(nbins1)
            nbins_top_level.append(nbins_top_level1)
            nbins_cats.append(nbins_cats1)
            seed.append(seed1)
            sample_rate.append(sample_rate1)
            sample_rate_per_class.append(sample_rate_per_class1)
            col_sample_rate_per_tree.append(col_sample_rate_per_tree1)
            col_sample_rate_change_per_level.append(col_sample_rate_change_per_level1)
            min_split_improvement.append(min_split_improvement1)
            histogram_type.append(histogram_type1)
            learn_rate.append(learn_rate1)
            learn_rate_annealing.append(learn_rate_annealing1)
            col_sample_rate.append(col_sample_rate1)
            max_abs_leafnode_pred.append(max_abs_leafnode_pred1)
            pred_noise_bandwidth.append(pred_noise_bandwidth1)
            distribution.append(distribution1)
            tweedie_power.append(tweedie_power1)
            quantile_alpha.append(quantile_alpha1)
            huber_alpha.append(huber_alpha1)
            categorical_encoding.append(categorical_encoding1)
            
gbm_df = pd.DataFrame(data={"Model Name":model_name,"weights_column":weights_column,
                        'offset_column':offset_column, 'fold_column':fold_column, 
                        'fold_assessment':fold_assignment, 'stopping_rounds':stopping_rounds, 
                        'max_runtime_secs':max_runtime_secs, 'stopping_metric':stopping_metric, 
                        'stopping_tolerance':stopping_tolerance, 'balance_classes':balance_classes, 
                        'class_sampling_factors':class_sampling_factors, 'max_after_balance_size':max_after_balance_size,
                        'ntrees':ntrees, 'max_depth':max_depth, 'min_rows':min_rows, 'nbins':nbins, 
                        'nbins_top_level':nbins_top_level, 'nbins_cats':nbins_cats, "seed":seed, 
                        'sample_rate':sample_rate, 'sample_rate_per_class':sample_rate_per_class, 
                        'col_sample_rate_per_tree':col_sample_rate_per_tree, 'col_sample_rate_change_per_level':col_sample_rate_change_per_level, 
                        'min_split_improvement':min_split_improvement, 'histogram_type':histogram_type, 
                        'learn_rate':learn_rate,'learn_rate_annealing' :learn_rate_annealing, 
                        'col_sample_rate':col_sample_rate, 'max_abs_leafnode_pred':max_abs_leafnode_pred, 
                        'pred_noise_bandwidth':pred_noise_bandwidth, 'distribution':distribution, 
                        'tweedie_power':tweedie_power,'quantile_alpha':quantile_alpha,
                        'huber_alpha':huber_alpha,'categorical_encoding':categorical_encoding})
gbm_df.fillna("NULL", inplace = True)
gbm_df.to_csv("GBM.csv",sep=',', index=False)

# %%
gbm_df.head(5)
# Out:
#                      Model Name weights_column offset_column fold_column  \
# 0  GBM_4_AutoML_20190416_233703           NULL          NULL        NULL
# 1  GBM_2_AutoML_20190416_233703           NULL          NULL        NULL
# 2  GBM_3_AutoML_20190416_233703           NULL          NULL        NULL
# 3  GBM_1_AutoML_20190416_233703           NULL          NULL        NULL
# 4  GBM_5_AutoML_20190416_233703           NULL          NULL        NULL
#
#   fold_assessment  stopping_rounds  max_runtime_secs stopping_metric  \
# 0          Modulo                0               0.0        deviance
# 1          Modulo                0               0.0        deviance
# 2          Modulo                0               0.0        deviance
# 3          Modulo                0               0.0        deviance
# 4          Modulo                0               0.0        deviance
#
#    stopping_tolerance  balance_classes          ...          learn_rate  \
# ...

# %%
#GLM
modelid=[]
weights_col=[]
offset_colu=[]
fold_colu=[]
fold_assign=[]
stopping_round=[]
max_runtim=[]
stopping_met=[]
stopping_tole=[]
seedd=[]
tweedie_variance=[]
tweedie_link=[]
alph=[]
lambda1=[]
missing_values=[]
standard=[]
#theta2=[]

for i in range(len(d)):
    if d[i]['model_id']['actual']['name'].startswith('GLM'):
        model=d[i]['model_id']['actual']['name']
        weights = d[i]['weights_column']['actual']
        offset= d[i]['offset_column']['actual']
        fold= d[i]['fold_column']['actual']
        fold_ass= d[i]['fold_assignment']['actual']
        max_runtime=d[i]['max_runtime_secs']['actual']
        seeds=d[i]['seed']['actual']
        tw_variance=d[i]['tweedie_variance_power']['actual']
        tw_link=d[i]['tweedie_link_power']['actual']
        alpha1=d[i]['alpha']['actual']
        lamb=d[i]['lambda']['actual']
        missing=d[i]['missing_values_handling']['actual']
        stand=d[i]['standardize']['actual']
        #theta1=d[i]['theta']['actual']
        
        modelid.append(model)
        weights_col.append(weights)
        offset_colu.append(offset)
        fold_colu.append(fold)
        fold_assign.append(fold_ass)
        seedd.append(seeds)
        tweedie_variance.append(tw_variance)
        tweedie_link.append(tw_link)
        alph.append(alpha1)
        lambda1.append(lamb)
        missing_values.append(missing)
        standard.append(stand)
        #theta2.append(theta1)
    
glm_df = pd.DataFrame(data={"Model_Name":modelid,"weights_column":weights_col,
                            'offset_column':offset_colu,"fold_column":fold_colu,
                            "fold_assign":fold_assign,"seed":seedd,"tweedie_variance_power":tweedie_variance,
                            "tweedie_link_power":tweedie_link,"alpha":alph,"lambda":lambda1,
                            "missing_values_handling":missing_values,"standardize":standard}) #'theta':theta
glm_df.fillna("NULL", inplace = True)
#glm_df.index.names=['G_Hyperparameter_ID']
glm_df.to_csv("GLM.csv",sep=',', index=False)

# %%
glm_df.head(5)
# Out:
#                                   Model_Name weights_column offset_column  \
# 0  GLM_grid_1_AutoML_20190416_233703_model_1           NULL          NULL
# 1  GLM_grid_1_AutoML_20190417_103626_model_1           NULL          NULL
# 2  GLM_grid_1_AutoML_20190417_092107_model_1           NULL          NULL
# 3  GLM_grid_1_AutoML_20190417_121910_model_1           NULL          NULL
# 4  GLM_grid_1_AutoML_20190419_190006_model_1           NULL          NULL
#
#   fold_column fold_assign                 seed  tweedie_variance_power  \
# 0        NULL      Modulo  3605434411294760589                     0.0
# 1        NULL      Modulo  1695358159836644228                     0.0
# 2        NULL      Modulo -4293711706793077853                     0.0
# 3        NULL      Modulo  1411290820467823314                     0.0
# 4        NULL      Modulo  2106761952620105859                     0.0
#
#    tweedie_link_power                           alpha  \
# ...

# %%
#DRF
lmodel=[]
lweights_column=[]
loffset_column=[]
lfold_column=[]
lfold_assignment=[]
lstopping_rounds=[]
lmax_runtime_secs=[]
lstopping_metric=[]
lstopping_tolerance=[]
lbalance_classes=[]
lclass_sampling_factors=[]
lmax_after_balance_size=[]
lntrees=[]
lmax_depth=[]
lmin_rows=[]
lnbins=[]
lnbins_top_level=[]
lnbins_cats=[]
lseed=[]
lsample_rate=[]
lsample_rate_per_class=[]
lcol_sample_rate_per_tree=[]
lcol_sample_rate_change_per_level=[]
lmin_split_improvement=[]
lhistogram_type=[]
lmtries=[]
lcategorical_encoding=[]

for i in range(len(d)):
    if d[i]['model_id']['actual']['name'].startswith('DRF'):
        model=d[i]['model_id']['actual']['name']
        weights_column = d[i]['weights_column']['actual']
        offset_column= d[i]['offset_column']['actual']
        fold_column= d[i]['fold_column']['actual']
        fold_assignment= d[i]['fold_assignment']['actual']
        stopping_rounds=d[i]['stopping_rounds']['actual']
        max_runtime_secs=d[i]['max_runtime_secs']['actual']
        stopping_metric=d[i]['stopping_metric']['actual']
        stopping_tolerance=d[i]['stopping_tolerance']['actual']
        balance_classes=d[i]['balance_classes']['actual']
        class_sampling_factors=d[i]['class_sampling_factors']['actual']
        max_after_balance_size=d[i]['max_after_balance_size']['actual']
        ntrees=d[i]['ntrees']['actual']
        max_depth=d[i]['max_depth']['actual']
        min_rows=d[i]['min_rows']['actual']
        nbins=d[i]['nbins']['actual']
        nbins_top_level=d[i]['nbins_top_level']['actual']
        nbins_cats=d[i]['nbins_cats']['actual']
        seed=d[i]['seed']['actual']
        sample_rate=d[i]['sample_rate']['actual']
        sample_rate_per_class=d[i]['sample_rate_per_class']['actual']
        col_sample_rate_per_tree=d[i]['col_sample_rate_per_tree']['actual']
        col_sample_rate_change_per_level=d[i]['col_sample_rate_change_per_level']['actual']
        min_split_improvement=d[i]['min_split_improvement']['actual']
        histogram_type=d[i]['histogram_type']['actual']
        mtries=d[i]['mtries']['actual']
        categorical_encoding=d[i]['categorical_encoding']['actual']
        
        lmodel.append(model)
        lweights_column.append(weights_column) 
        loffset_column.append(offset_column)
        lfold_column.append(fold_column)
        lfold_assignment.append(fold_assignment)
        lstopping_rounds.append(stopping_rounds)
        lmax_runtime_secs.append(max_runtime_secs)
        lstopping_metric.append(stopping_metric)
        lstopping_tolerance.append(stopping_tolerance)
        lbalance_classes.append(balance_classes)
        lclass_sampling_factors.append(class_sampling_factors)
        lmax_after_balance_size.append(max_after_balance_size)
        lntrees.append(ntrees)
        lmax_depth.append(max_depth)
        lmin_rows.append(min_rows)
        lnbins.append(nbins)
        lnbins_top_level.append(nbins_top_level)
        lnbins_cats.append(nbins_cats)
        lseed.append(seed)
        lsample_rate.append(sample_rate)
        lsample_rate_per_class.append(sample_rate_per_class)
        lcol_sample_rate_per_tree.append(col_sample_rate_per_tree)
        lcol_sample_rate_change_per_level.append(col_sample_rate_change_per_level)
        lmin_split_improvement.append(min_split_improvement)
        lhistogram_type.append(histogram_type)
        lmtries.append(mtries)
        lcategorical_encoding.append(categorical_encoding)
        
drf_df = pd.DataFrame(data={"Model_Name":lmodel,"weights_column":lweights_column,
                            "offset_column":loffset_column,"fold_column":lfold_column,
                            "fold_assignment":lfold_assignment,"stopping_rounds":lstopping_rounds,
                            "max_runtime_secs":lmax_runtime_secs,"stopping_metric":lstopping_metric,
                            "stopping_tolerance":lstopping_tolerance,"balance_classes":lbalance_classes,
                            "class_sampling_factors":lclass_sampling_factors,"max_after_balance_size":lmax_after_balance_size,
                            "ntrees":lntrees,"max_depth":lmax_depth,"min_rows":lmin_rows,"nbins":lnbins,
                            "nbins_top_level":lnbins_top_level,"nbins_cats":lnbins_cats,"seed":lseed,
                            "sample_rate":lsample_rate,"sample_rate_per_class":lsample_rate_per_class,
                            "col_sample_rate_per_tree":lcol_sample_rate_per_tree,"col_sample_rate_change_per_level":lcol_sample_rate_change_per_level,
                            "min_split_improvement":lmin_split_improvement,"histogram_type":lhistogram_type,
                            "mtries":lmtries,"categorical_encoding":lcategorical_encoding})

drf_df.fillna("NULL", inplace = True)
drf_df.to_csv("DRF.csv",sep=',', index=False)

# %%
drf_df.head(5)
# Out:
#                      Model_Name weights_column offset_column fold_column  \
# 0  DRF_1_AutoML_20190416_233703           NULL          NULL        NULL
# 1  DRF_1_AutoML_20190417_103626           NULL          NULL        NULL
# 2  DRF_1_AutoML_20190417_092107           NULL          NULL        NULL
# 3  DRF_1_AutoML_20190417_121910           NULL          NULL        NULL
# 4  DRF_1_AutoML_20190419_190006           NULL          NULL        NULL
#
#   fold_assignment  stopping_rounds  max_runtime_secs stopping_metric  \
# 0          Modulo                0               0.0            AUTO
# 1          Modulo                0               0.0        deviance
# 2          Modulo                0               0.0            AUTO
# 3          Modulo                0               0.0            AUTO
# 4          Modulo                0               0.0        deviance
#
#    stopping_tolerance  balance_classes          ...          nbins_cats  \
# ...

# %%
#XRT
lmodel=[]
lweights_column=[]
loffset_column=[]
lfold_column=[]
lfold_assignment=[]
lstopping_rounds=[]
lmax_runtime_secs=[]
lstopping_metric=[]
lstopping_tolerance=[]
lbalance_classes=[]
lclass_sampling_factors=[]
lmax_after_balance_size=[]
lntrees=[]
lmax_depth=[]
lmin_rows=[]
lnbins=[]
lnbins_top_level=[]
lnbins_cats=[]
lseed=[]
lsample_rate=[]
lsample_rate_per_class=[]
lcol_sample_rate_per_tree=[]
lcol_sample_rate_change_per_level=[]
lmin_split_improvement=[]
lhistogram_type=[]
lmtries=[]
lcategorical_encoding=[]

for i in range(len(d)):
    if d[i]['model_id']['actual']['name'].startswith('XRT'):
        model=d[i]['model_id']['actual']['name']
        weights_column = d[i]['weights_column']['actual']
        offset_column= d[i]['offset_column']['actual']
        fold_column= d[i]['fold_column']['actual']
        fold_assignment= d[i]['fold_assignment']['actual']
        stopping_rounds=d[i]['stopping_rounds']['actual']
        max_runtime_secs=d[i]['max_runtime_secs']['actual']
        stopping_metric=d[i]['stopping_metric']['actual']
        stopping_tolerance=d[i]['stopping_tolerance']['actual']
        balance_classes=d[i]['balance_classes']['actual']
        class_sampling_factors=d[i]['class_sampling_factors']['actual']
        max_after_balance_size=d[i]['max_after_balance_size']['actual']
        ntrees=d[i]['ntrees']['actual']
        max_depth=d[i]['max_depth']['actual']
        min_rows=d[i]['min_rows']['actual']
        nbins=d[i]['nbins']['actual']
        nbins_top_level=d[i]['nbins_top_level']['actual']
        nbins_cats=d[i]['nbins_cats']['actual']
        seed=d[i]['seed']['actual']
        sample_rate=d[i]['sample_rate']['actual']
        sample_rate_per_class=d[i]['sample_rate_per_class']['actual']
        col_sample_rate_per_tree=d[i]['col_sample_rate_per_tree']['actual']
        col_sample_rate_change_per_level=d[i]['col_sample_rate_change_per_level']['actual']
        min_split_improvement=d[i]['min_split_improvement']['actual']
        histogram_type=d[i]['histogram_type']['actual']
        mtries=d[i]['mtries']['actual']
        categorical_encoding=d[i]['categorical_encoding']['actual']
        
        lmodel.append(model)
        lweights_column.append(weights_column) 
        loffset_column.append(offset_column)
        lfold_column.append(fold_column)
        lfold_assignment.append(fold_assignment)
        lstopping_rounds.append(stopping_rounds)
        lmax_runtime_secs.append(max_runtime_secs)
        lstopping_metric.append(stopping_metric)
        lstopping_tolerance.append(stopping_tolerance)
        lbalance_classes.append(balance_classes)
        lclass_sampling_factors.append(class_sampling_factors)
        lmax_after_balance_size.append(max_after_balance_size)
        lntrees.append(ntrees)
        lmax_depth.append(max_depth)
        lmin_rows.append(min_rows)
        lnbins.append(nbins)
        lnbins_top_level.append(nbins_top_level)
        lnbins_cats.append(nbins_cats)
        lseed.append(seed)
        lsample_rate.append(sample_rate)
        lsample_rate_per_class.append(sample_rate_per_class)
        lcol_sample_rate_per_tree.append(col_sample_rate_per_tree)
        lcol_sample_rate_change_per_level.append(col_sample_rate_change_per_level)
        lmin_split_improvement.append(min_split_improvement)
        lhistogram_type.append(histogram_type)
        lmtries.append(mtries)
        lcategorical_encoding.append(categorical_encoding)
        
xrt_df = pd.DataFrame(data={"Model_Name":lmodel,"weights_column":lweights_column,
                            "offset_column":loffset_column,"fold_column":lfold_column,
                            "fold_assignment":lfold_assignment,"stopping_rounds":lstopping_rounds,
                            "max_runtime_secs":lmax_runtime_secs,"stopping_metric":lstopping_metric,
                            "stopping_tolerance":lstopping_tolerance,"balance_classes":lbalance_classes,
                            "class_sampling_factors":lclass_sampling_factors,"max_after_balance_size":lmax_after_balance_size,
                            "ntrees":lntrees,"max_depth":lmax_depth,"min_rows":lmin_rows,"nbins":lnbins,
                            "nbins_top_level":lnbins_top_level,"nbins_cats":lnbins_cats,"seed":lseed,
                            "sample_rate":lsample_rate,"sample_rate_per_class":lsample_rate_per_class,
                            "col_sample_rate_per_tree":lcol_sample_rate_per_tree,"col_sample_rate_change_per_level":lcol_sample_rate_change_per_level,
                            "min_split_improvement":lmin_split_improvement,"histogram_type":lhistogram_type,
                            "mtries":lmtries,"categorical_encoding":lcategorical_encoding})
xrt_df.fillna("NULL", inplace = True)
xrt_df.to_csv("XRT.csv",sep=',', index=False)

# %%
xrt_df.head(5)
# Out:
#                      Model_Name weights_column offset_column fold_column  \
# 0  XRT_1_AutoML_20190416_233703           NULL          NULL        NULL
# 1  XRT_1_AutoML_20190417_092107           NULL          NULL        NULL
# 2  XRT_1_AutoML_20190417_103626           NULL          NULL        NULL
# 3  XRT_1_AutoML_20190417_121910           NULL          NULL        NULL
# 4  XRT_1_AutoML_20190419_190006           NULL          NULL        NULL
#
#   fold_assignment  stopping_rounds  max_runtime_secs stopping_metric  \
# 0          Modulo                0               0.0        deviance
# 1          Modulo                0               0.0        deviance
# 2          Modulo                0               0.0        deviance
# 3          Modulo                0               0.0        deviance
# 4          Modulo                0               0.0        deviance
#
#    stopping_tolerance  balance_classes          ...          nbins_cats  \
# ...

# %%
#Leaderboard Table
l500 = pd.read_csv("hlE1w6gySMelbournehousingprices_500_leaderboard.csv")
l800 = pd.read_csv("ilkMo6dfRMelbournehousingprices_800_leaderboard.csv")
l1000 = pd.read_csv("aGXJjUoV5Melbournehousingprices_1300_leaderboard.csv")
l1300 = pd.read_csv("q077P1c6BMelbournehousingprices_1000_leaderboard.csv")
l1500 = pd.read_csv("ljms5EdOlMelbournehousingprices_1500_leaderboard.csv")
ldf = pd.concat([l500,l800,l1000,l1300,l1500])
ldf.columns = ['Model_ID','Model_Name','Mean_Residual_Deviance','RMSE','MSE','MAE','RMSLE']
ldf['Model_ID']= np.arange(1, len(ldf)+1)
ldf.to_csv("Model Metrics.csv",sep=',', index=True)
ldf.head(5)
# Out:
#    Model_ID                    Model_Name  Mean_Residual_Deviance  \
# 0         1  GBM_4_AutoML_20190416_233703            9.166265e+10
# 1         2  GBM_2_AutoML_20190416_233703            9.190349e+10
# 2         3  GBM_3_AutoML_20190416_233703            9.220339e+10
# 3         4  GBM_1_AutoML_20190416_233703            9.350637e+10
# 4         5  GBM_5_AutoML_20190416_233703            9.680501e+10
#
#             RMSE           MSE            MAE     RMSLE
# 0  302758.397076  9.166265e+10  171470.704864  0.204274
# 1  303155.882459  9.190349e+10  171952.833449  0.205054
# 2  303650.103117  9.220339e+10  171105.736796  0.203580
# 3  305788.113016  9.350637e+10  173001.133033  0.206323
# 4  311135.028276  9.680501e+10  176070.718723  0.208741

# %%
#Metadatatable

M500= json.load(open("hlE1w6gySMelbHousingPrices_500_meta_data.json"))
M800= json.load(open("ilkMo6dfRMelbHousingPrices_800_meta_data.json"))
M1000=json.load(open("q077P1c6BMelbHousingPrices_1000_meta_data.json"))
M1300=json.load(open("aGXJjUoV5MelbHousingPrices_1300_meta_data.json"))
M1500=json.load(open('ljms5EdOlMelbHousingPrices_1500_meta_data.json'))

m=[M500,M800,M1000,M1500,M1300,M1500]
runs=[]
run_id=[]
models=[]
time=[]
for i in range(len(m)):
    run=m[i]['run_time']
    model=m[i]['Models_generated']
    exectime=m[i]['model_execution_time_sec']
    runid=m[i]['run_id']
    runs.append(run)
    models.append(model)
    time.append(exectime)
    run_id.append(runid)

runtime_df = pd.DataFrame(data={'Runtime_ID':np.arange(1, len(runs)+1),'Dataset_ID':1,
                                "run_time":runs,"Models_generated":models,
                                'model_execution_time_sec':time})
runtime_df.fillna("NULL", inplace = True)
runtime_df.to_csv("Metadata.csv",sep=',', index=False) 
runtime_df
# Out:
#    Runtime_ID  Dataset_ID  run_time  Models_generated  \
# 0           1           1       500                12
# 1           2           1       800                30
# 2           3           1      1000                16
# 3           4           1      1500                22
# 4           5           1      1300                23
# 5           6           1      1500                22
#
#    model_execution_time_sec
# 0                529.548963
# 1                807.102153
# 2               1006.535758
# 3               1955.460279
# 4               1418.183251
# 5               1955.460279

# %%
#Dataset description table
record1=[]
column=[]
dtypes=[]
for i in range(len(dataset.columns)):
    records1=dataset[dataset.columns[i]].count()
    dtype=dataset[dataset.columns[i]].dtypes
    col_name=dataset.columns[i]
    record1.append(records1)
    column.append(col_name)
    dtypes.append(dtype)
df2=pd.DataFrame(data = {'Column_ID':np.arange(1, len(dataset.columns)+1),
                         'Column_Name':column ,'Data_Type':dtypes,'Total_Records':record1,
                         'Target':"Price",'Prediction_Type':"Regression"})
df2.to_csv("Dataset Description.csv")
df2.head(5)
# Out:
#    Column_ID Column_Name Data_Type  Total_Records Target Prediction_Type
# 0          1      Suburb    object          34857  Price      Regression
# 1          2     Address    object          34857  Price      Regression
# 2          3       Rooms     int64          34857  Price      Regression
# 3          4        Type    object          34857  Price      Regression
# 4          5       Price   float64          27247  Price      Regression
